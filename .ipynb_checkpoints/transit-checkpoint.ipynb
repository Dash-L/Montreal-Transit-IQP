# %%
using Gadfly

# %%
using DataFrames, CSV
ntd_df = CSV.read("ntd_2023.csv", DataFrame);
us_census_df = CSV.read("us_census_2020.csv", DataFrame);

# %%
@from row in ntd_df begin
    @where row.uza_name == "New York--Jersey City--Newark, NY--NJ"
    @select row
    @collect DataFrame
end
# Out:
# 66×39 DataFrame
#  Row │ agency                             city                state    ntd_id  ⋯
#      │ String                             String31?           String3  Int64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ City of Long Beach                 Long Beach          NY        20006  ⋯
#    2 │ City of Long Beach                 Long Beach          NY        20006
#    3 │ MTA New York City Transit          Brooklyn            NY        20008
#    4 │ MTA New York City Transit          Brooklyn            NY        20008
#    5 │ MTA New York City Transit          Brooklyn            NY        20008  ⋯
#    6 │ MTA New York City Transit          Brooklyn            NY        20008
#    7 │ MTA New York City Transit          Brooklyn            NY        20008
#    8 │ Town of Huntington, dba: Hunting…  Huntington          NY        20071
#    9 │ Town of Huntington, dba: Hunting…  Huntington          NY        20071  ⋯
#   10 │ Suffolk County , dba: Suffolk Co…  Yaphank             NY        20072
#   11 │ Suffolk County , dba: Suffolk Co…  Yaphank             NY        20072
#   ⋮  │                 ⋮                          ⋮              ⋮       ⋮     ⋱
#   57 │ Morris County, dba: Morris Area …  Morristown          NJ        20210
#   58 │ County of Hunterdon, dba: HCLink   Flemington          NJ        20212  ⋯
#   59 │ County of Hunterdon, dba: HCLink   Flemington          NJ        20212
#   60 │ Hampton Jitney, Inc.               Calverton           NY        20217
#   61 │ Broadway Bus Corporation           Bayonne             NJ        20220
#   62 │ SeaStreak, LLC                     Atlantic Highlands  NJ        20226  ⋯
#   63 │ Barnegat Bay Decoy & Baymen's Mu…  Tuckerton           NJ        20230
#   64 │ Monmouth County, dba: Special Ci…  Freehold            NJ        20933
#   65 │ New York City Economic Developme…  New York            NY        22930
#   66 │ New York City Economic Developme…  New York            NY        22930  ⋯
#                                                   35 columns and 45 rows omitted

# %%
metro_areas1 = [
    "New York--Jersey City--Newark, NY--NJ"
    "Los Angeles--Long Beach--Anaheim, CA"
    "Chicago, IL--IN"
    "Miami--Fort Lauderdale, FL"
    "Houston, TX"
    "Dallas--Fort Worth--Arlington, TX"
]
metro_areas2 = [
    "Philadelphia, PA--NJ--DE--MD"
    "Washington--Arlington, DC--VA--MD"
    "Atlanta, GA"
    "Boston, MA--NH"
    "Seattle--Tacoma, WA"
    "San Francisco--Oakland, CA"
    "San Diego, CA"
];

parsed = @from ntd_row in ntd_df begin
    @where ntd_row.primary_uza_population >= 0
    @join area in metro_areas1 on ntd_row.uza_name[] equals area
    @group ntd_row by ntd_row.uza_name into g
    @join census_row in us_census_df on key(g) equals census_row[2] into x
    @let population = first(g.primary_uza_population)
    @let land_area = sum(map(c -> parse(Int64,replace(c[7][], r","=>"")), x))
    @let metro_area=key(g)[]
    @select {
        metro_area,
        name=metro_area[1:findfirst(c -> c == ',' || c == '-', metro_area)-1],
        rides_per_capita=sum(g.unlinked_passenger_trips ./ g.primary_uza_population),
        population,
        population_density=population / (land_area / 1000^2),
        country=:us
    }
    @collect DataFrame
end

append!(parsed, @from ntd_row in ntd_df begin
    @where ntd_row.primary_uza_population >= 0
    @join area in metro_areas2 on ntd_row.uza_name[] equals area
    @group ntd_row by ntd_row.uza_name into g
    @join census_row in us_census_df on key(g) equals census_row[2] into x
    @let population = first(g.primary_uza_population)
    @let land_area = sum(map(c -> parse(Int64,replace(c[7][], r","=>"")), x))
    @let metro_area=key(g)[]
    @select {
        metro_area,
        name=metro_area[1:findfirst(c -> c == ',' || c == '-', metro_area)-1],
        rides_per_capita=sum(g.unlinked_passenger_trips ./ g.primary_uza_population),
        population,
        population_density=population / (land_area / 1000^2),
        country=:canada
    }
    @collect DataFrame
end)
# Out:
# 13×6 DataFrame
#  Row │ metro_area                         name           rides_per_capita  pop ⋯
#      │ String                             String         Float64?          Int ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ New York--Jersey City--Newark, N…  New York              167.116      1 ⋯
#    2 │ Miami--Fort Lauderdale, FL         Miami                  18.9409
#    3 │ Chicago, IL--IN                    Chicago                38.3212
#    4 │ Dallas--Fort Worth--Arlington, TX  Dallas                  9.74154
#    5 │ Houston, TX                        Houston                11.7942       ⋯
#    6 │ Los Angeles--Long Beach--Anaheim…  Los Angeles            31.7221     1
#    7 │ Seattle--Tacoma, WA                Seattle                43.0793
#    8 │ Boston, MA--NH                     Boston                 54.9247
#    9 │ Philadelphia, PA--NJ--DE--MD       Philadelphia           37.1115       ⋯
#   10 │ Washington--Arlington, DC--VA--MD  Washington             52.146
#   11 │ Atlanta, GA                        Atlanta                12.791
#   12 │ San Francisco--Oakland, CA         San Francisco          71.1345
#   13 │ San Diego, CA                      San Diego              24.9788       ⋯
#                                                                3 columns omitted

# %%
transit_agencies1 = [
    "MTA New York City Transit"
    "Los Angeles County Metropolitan Transportation Authority , dba: Metro"
    "Chicago Transit Authority"
    "County of Miami-Dade"
    "Metropolitan Transit Authority of Harris County, Texas , dba: METRO"
    "Dallas Area Rapid Transit"
]
transit_agencies2 = [
    "Southeastern Pennsylvania Transportation Authority"
    "Washington Metropolitan Area Transit Authority, dba: Washington Metro"
    "Metropolitan Atlanta Rapid Transit Authority"
    "Massachusetts Bay Transportation Authority"
    "King County, dba: King County Metro"
    "City and County of San Francisco, dba: San Francisco Municipal Transportation Agency"
    "San Diego Metropolitan Transit System"
];

parsed2 = @from ntd_row in ntd_df begin
    @where ntd_row.primary_uza_population >= 0
    @join agency in transit_agencies1 on ntd_row.agency equals agency
    @group ntd_row by ntd_row.uza_name into g
    @join census_row in us_census_df on key(g) equals census_row[2] into x
    @let population = first(g.primary_uza_population)
    @let land_area = sum(map(c -> parse(Int64,replace(c[7][], r","=>"")), x))
    @let metro_area=key(g)[]
    @select {
        metro_area,
        name=metro_area[1:findfirst(c -> c == ',' || c == '-', metro_area)-1],
        rides_per_capita=sum(g.unlinked_passenger_trips ./ g.primary_uza_population),
        population,
        population_density=population / (land_area / 1000^2),
        country=:us
    }
    @collect DataFrame
end

append!(parsed2, @from ntd_row in ntd_df begin
    @where ntd_row.primary_uza_population >= 0
    @join agency in transit_agencies2 on ntd_row.agency equals agency
    @group ntd_row by ntd_row.uza_name into g
    @join census_row in us_census_df on key(g) equals census_row[2] into x
    @let population = first(g.primary_uza_population)
    @let land_area = sum(map(c -> parse(Int64,replace(c[7][], r","=>"")), x))
    @let metro_area=key(g)[]
    @select {
        metro_area,
        name=metro_area[1:findfirst(c -> c == ',' || c == '-', metro_area)-1],
        rides_per_capita=sum(g.unlinked_passenger_trips ./ g.primary_uza_population),
        population,
        population_density=population / (land_area / 1000^2),
        country=:canada
    }
    @collect DataFrame
end)
# Out:
# 13×6 DataFrame
#  Row │ metro_area                         name           rides_per_capita  pop ⋯
#      │ String                             String         Float64?          Int ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ New York--Jersey City--Newark, N…  New York              135.486      1 ⋯
#    2 │ Miami--Fort Lauderdale, FL         Miami                  12.8279
#    3 │ Chicago, IL--IN                    Chicago                32.1903
#    4 │ Houston, TX                        Houston                11.7152
#    5 │ Dallas--Fort Worth--Arlington, TX  Dallas                  8.50199      ⋯
#    6 │ Los Angeles--Long Beach--Anaheim…  Los Angeles            22.5786     1
#    7 │ Seattle--Tacoma, WA                Seattle                22.2592
#    8 │ Boston, MA--NH                     Boston                 53.6228
#    9 │ Philadelphia, PA--NJ--DE--MD       Philadelphia           34.6314       ⋯
#   10 │ Washington--Arlington, DC--VA--MD  Washington             44.6444
#   11 │ Atlanta, GA                        Atlanta                12.1748
#   12 │ San Francisco--Oakland, CA         San Francisco          39.5706
#   13 │ San Diego, CA                      San Diego              22.3142       ⋯
#                                                                3 columns omitted

# %%
p1 = plot(parsed, x=:population_density, y=:rides_per_capita, size=:population, label=:name, color=:country, alpha=[.5],
    Scale.size_area((p; min=.5mm, max=4mm) -> min + p*(max-min), minvalue=minimum(parsed.population), maxvalue=maximum(parsed.population)),
    Scale.color_discrete_manual(colorant"aqua", colorant"red"),
    Guide.xlabel("Population Density (people per square kilometer)"),
    Guide.ylabel("Rides Per Capita"),
    Guide.title("Rides Per Capita vs Population Density (2023)"),
    Guide.xticks(ticks=(1:6)*500),
    Geom.point,
    Geom.label(position=:dynamic, hide_overlaps=false),
    Coord.cartesian(xmin=500),
    Theme(key_position=:none, grid_line_width=.5mm, grid_line_style=:solid, point_label_font_size=12pt, major_label_font_size=16pt, discrete_highlight_color=x->"black")
)
p2 = plot(parsed2, x=:population_density, y=:rides_per_capita, size=:population, label=:name, color=:country, alpha=[.5],
    Scale.size_area((p; min=.5mm, max=4mm) -> min + p*(max-min), minvalue=minimum(parsed.population), maxvalue=maximum(parsed.population)),
    Scale.color_discrete_manual(colorant"aqua", colorant"red"),
    Guide.xlabel("Population Density (people per square kilometer)"),
    Guide.ylabel("Rides Per Capita"),
    Guide.title("Rides Per Capita vs Population Density (2023)"),
    Guide.xticks(ticks=(1:6)*500),
    Geom.point,
    Geom.label(position=:dynamic, hide_overlaps=false),
    Coord.cartesian(xmin=500),
    Theme(key_position=:none, grid_line_width=.5mm, grid_line_style=:solid, point_label_font_size=12pt, major_label_font_size=16pt, discrete_highlight_color=x->"black")
)
import Cairo, Fontconfig
out = hstack(p1, p2)
# Out:
# Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:cx, Int64}, Measures.Length{:cy, Int64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0cx, 0cy), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.5w, 0.0h), (0.5w, 1.0h)), nothing, nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.AbsoluteLength, Measures.AbsoluteLength}, Tuple{Measures.Add{Measures.Add{Measures.Length{:w, Float64}, Measures.AbsoluteLength}, Measures.AbsoluteLength}, Measures.Add{Measures.Add{Measures.Length{:h, Float64}, Measures.AbsoluteLength}, Measures.AbsoluteLength}}}((5.0mm, 5.0mm), (1.0w + -5.0mm + -5.0mm, 1.0h + -5.0mm + -5.0mm)), nothing, nothing, nothing, nothing, List([Compose.Table(Vector{Compose.Context}[[] [] [Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), Compose.UnitBox{Int64, Float64, Float64, Float64}(500, 150.0, 2500.0, -150.0, 2.0mm, 2.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([]), List([Compose.Form{Compose.TextPrimitive{Tuple{Measures.Length{:w, Float64}, Measures.Add{Measures.Add{Measures.Length{:h, Float64}, Measures.AbsoluteLength}, Measures.AbsoluteLength}}, Compose.Rotation{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}, Tuple{Measures.AbsoluteLength, Measures.AbsoluteLength}}}(Compose.TextPrimitive{Tuple{Measures.Length{:w, Float64}, Measures.Add{Measures.Add{Measures.Length{:h, Float64}, Measures.AbsoluteLength}, Measures.AbsoluteLength}}, Compose.Rotation{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}, Tuple{Measures.AbsoluteLength, Measures.AbsoluteLength}}[Compose.TextPrimitive{Tuple{Measures.Length{:w, Float64}, Measures.Add{Measures.Add{Measures.Length{:h, Float64}, Measures.AbsoluteLength}, Measures.AbsoluteLength}}, Compose.Rotation{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}, Tuple{Measures.AbsoluteLength, Measures.AbsoluteLength}}((0.5w, 1.0h + -5.644444444444444mm + -2.0mm), "Rides Per Capita vs Population Density (2023)", Compose.HCenter(), Compose.VTop(), Compose.Rotation{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}(0.0, (0.5w, 0.5h)), (0.0mm, 0.0mm))], Symbol(""))]), List([Compose.Property{Compose.FontSizePrimitive}(Compose.FontSizePrimitive[Compose.FontSizePrimitive(5.644444444444444mm)]), Compose.Property{Compose.FontPrimitive}(Compose.FontPrimitive[Compose.FontPrimitive("'PT Sans','Helvetica Neue','Helvetica',sans-serif")]), Compose.Property{Compose.FillPrimitive}(Compose.FillPrimitive[Compose.FillPrimitive(RGBA{Float64}(0.33725490196078434, 0.2901960784313726, 0.3333333333333333, 1.0))]), Compose.Property{Compose.StrokePrimitive}(Compose.StrokePrimitive[Compose.StrokePrimitive(RGBA{Float64}(0.0, 0.0, 0.0, 0.0))])]), 0, false, false, false, false, 109.00833333333333, 7.644444444444444, 0.0, Symbol(""))]; [Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), Compose.UnitBox{Int64, Float64, Float64, Float64}(500, 150.0, 2500.0, -150.0, 0.0mm, 0.0mm, 2.0mm, 2.0mm), nothing, nothing, nothing, List([Compose.AdhocContainerPromise(Gadfly.Guide.var"#render##42#render##43"{Gadfly.Guide.YLabel, Theme, Measures.AbsoluteLength}(Gadfly.Guide.YLabel("Rides Per Capita", :auto), Theme(LCHab{Float32}(70.0, 60.0, 240.0), 0.9mm, 0.45mm, 1.8mm, Gadfly.Scale.default_discrete_sizes, Gadfly.Scale.default_continuous_sizes, Gadfly.Scale.default_discrete_colors, Function[Compose.circle, Gadfly.Shape.square, Gadfly.Shape.diamond, Gadfly.Shape.cross, Gadfly.Shape.xcross, Gadfly.Shape.utriangle, Gadfly.Shape.dt ...
#   x=[2309.2111324396715, 1886.0242667128275, 1432.140390437394, 1289.493757575055, 1266.9750776571625, 2886.6095582615376, 1392.6984975707198, 1021.7501515638608, 1158.6229954708278, 1543.431382195352, 771.2978381061398, 2642.1143298517472, 1756.9398152761387]
#   y=[135.48554571141645, 12.827906669856565, 32.190345635123535, 11.71519695228984, 8.501986269515106, 22.578569703178196, 22.259199534087223, 53.6227917377623, 34.631423994382146, 44.644356191273836, 12.174837925127918, 39.57063260306723, 22.31422434289809]
#   size=Measures.AbsoluteLength[3.9494492332110065mm, 2.429373531745473mm, 2.8046571165793837mm, 2.3934927217974717mm, 2.373784092418334mm, 3.2377715025180605mm, 1.9733318490754213mm, 2.138285845785161mm, 2.367853463872367mm, 2.2803201643243836mm, 2.26743277099866mm, 1.967483888327228mm, 1.8713346601030691mm]
#   color=ColorTypes.RGB{Float32}[RGB(0.0, 1.0, 1.0), RGB(0.0, 1.0, 1.0), RGB(0.0, 1.0, 1.0), RGB(0.0, 1.0, 1.0), RGB(0.0, 1.0, 1.0), RGB(0.0, 1.0, 1.0), RGB(1.0, 0.0, 0.0), RGB(1.0, 0.0, 0.0), RGB(1.0, 0.0, 0.0), RGB(1.0, 0.0, 0.0), RGB(1.0, 0.0, 0.0), RGB(1.0, 0.0, 0.0), RGB(1.0, 0.0, 0.0)]
#   alpha=[0.5]
#   label=["New York", "Miami", "Chicago", "Houston", "Dallas", "Los Angeles", "Seattle", "Boston", "Philadelphia", "Washington", "Atlanta", "San Francisco", "San Diego"]
#   color_key_colors=OrderedCollections.OrderedDict{Any, Any}(RGB{Float32}(0.0, 1.0, 1.0) => 1, RGB{Float32}(1.0, 0.0, 0.0) => 2)
#   color_key_title="country"
#   titles=Dict{Symbol, AbstractString}(:color => "country", :alpha => "alpha", :y => "rides_per_capita", :label => "name", :size => "population", :x => "population_density")
#   size_key_title="population"
#   size_key_vals=OrderedCollections.OrderedDict{Measures.AbsoluteLength, Int64}(0.5mm => 1, 2.25mm => 2, 2.974873734152916mm => 3, 3.531088913245535mm => 4, 4.0mm => 5)
#   x_label=Gadfly.Scale.identity_formatter
#   y_label=Gadfly.Scale.identity_formatter
#   xtick_label=Showoff.showoff
#   ytick_label=Showoff.showoff
#   color_label=Gadfly.Scale.var"#labeler#apply_scale##10"{Dict{ColorTypes.RGB{Float32}, String}}(Dict{ColorTypes.RGB{Float32}, String}(RGB(0.0, 1.0, 1.0) => "us", RGB(1.0, 0.0, 0.0) => "canada"))
#   xgroup_label=Showoff.showoff
#   ygroup_label=Showoff.showoff
#   shape_label=Showoff.showoff
#   size_label=Gadfly.Scale.var"#labeler#apply_scale##37"{Dict{Measures.AbsoluteLength, String}}(Dict{Measures.AbsoluteLength, String}(0.5mm => "0", 3.531088913245535mm => "1.50×10⁷", 2.25mm => "5.00×10⁶", 4.0mm => "2.00×10⁷", 2.974873734152916mm => "1.00×10⁷"))
# )
# ), 0, false, false, nothing, nothing)]), List([]), List([]), 0, false, false, false, false, nothing, nothing, 0.0, Symbol("")), Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.TextPrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Compose.Rotation{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}, Tuple{Measures.AbsoluteLength, Measures.AbsoluteLength}}}(Compose.TextPrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Compose.Rotation{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}, Tuple{Measures.AbsoluteLength, Measures.AbsoluteLength}}[Compose.TextPrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Compose.Rotation{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}, Tuple{Measures.AbsoluteLength, Measures.AbsoluteLength}}((1756.9398152761387cx, 22.31422434289809cy), "1756.9398152761387\n22.31422434289809", Compose.HLeft(), Compose.VBottom(), Compose.Rotation{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}(0.0, (0.5w, 0.5h)), (0.0mm, 0.0mm))], Symbol(""))]), List([Compose.Property{Compose.JSCallPrimitive}(Compose.JSCallPrimitive[Compose.JSCallPrimitive("data(\"ilabel\", \"13canada\")\n.mouseenter(Gadfly.datatip_visible)\n.mouseleave(Gadfly.datatip_hidden)\n", Measures.Measure[])]), Compose.Property{Compose.FillOpacityPrimitive}(Compose.FillOpacityPrimitive[Compose.FillOpacityPrimitive(0.0)]), Compose.Property{Compose.SVGAttributePrimitive}(Compose.SVGAttributePrimitive[Compose.SVGAttributePrimitive("ilabel", "13canada")]), Compose.Property{Compose.SVGClassPrimitive}(Compose.SVGClassPrimitive[Compose.SVGClassPrimitive("datatip")])]), 2, false, false, false, false, nothing, nothing, 0.0, Symbol("")), Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.CirclePrimitive{Tuple{Measures.Measure, Measures.Measure}, Measures.Measure}}(Compose.CirclePrimitive{Tuple{Measures.Measure, Measures.Measure}, Measures.Measure}[Compose.CirclePrimitive{Tuple{Measures.Measure, Measures.Measure}, Measures.Measure}((1756.9398152761387cx, 22.31422434289809cy), 1.8713346601030691mm)], Symbol(""))]), List([Compose.Property{Compose.FillOpacityPrimitive}(Compose.FillOpacityPrimitive[Compose.FillOpacityPrimitive(0.5)]), Compose.Property{Compose.StrokePrimitive}(Compose.StrokePrimitive[Compose.StrokePrimitive(RGBA{Float64}(0.0, 0.0, 0.0, 1.0))]), Compose.Property{Compose.FillPrimitive}(Compose.FillPrimitive[Compose.FillPrimitive(RGBA{Float64}(1.0, 0.0, 0.0, 1.0))]), Compose.Property{Compose.SVGClassPrimitive}(Compose.S ...
#   x=[2309.2111324396715, 1886.0242667128275, 1432.140390437394, 1266.9750776571625, 1289.493757575055, 2886.6095582615376, 1392.6984975707198, 1021.7501515638608, 1158.6229954708278, 1543.431382195352, 771.2978381061398, 2642.1143298517472, 1756.9398152761387]
#   y=[167.11622659395948, 18.94094846550946, 38.321227812714994, 9.741540211926898, 11.794165958410034, 31.72213414052163, 43.079288692952694, 54.924677470995604, 37.11153687814084, 52.14602786332657, 12.79095419865289, 71.1344849290359, 24.97878578640524]
#   size=Measures.AbsoluteLength[3.9494492332110065mm, 2.429373531745473mm, 2.8046571165793837mm, 2.373784092418334mm, 2.3934927217974717mm, 3.2377715025180605mm, 1.9733318490754213mm, 2.138285845785161mm, 2.367853463872367mm, 2.2803201643243836mm, 2.26743277099866mm, 1.967483888327228mm, 1.8713346601030691mm]
#   color=ColorTypes.RGB{Float32}[RGB(0.0, 1.0, 1.0), RGB(0.0, 1.0, 1.0), RGB(0.0, 1.0, 1.0), RGB(0.0, 1.0, 1.0), RGB(0.0, 1.0, 1.0), RGB(0.0, 1.0, 1.0), RGB(1.0, 0.0, 0.0), RGB(1.0, 0.0, 0.0), RGB(1.0, 0.0, 0.0), RGB(1.0, 0.0, 0.0), RGB(1.0, 0.0, 0.0), RGB(1.0, 0.0, 0.0), RGB(1.0, 0.0, 0.0)]
#   alpha=[0.5]
#   label=["New York", "Miami", "Chicago", "Dallas", "Houston", "Los Angeles", "Seattle", "Boston", "Philadelphia", "Washington", "Atlanta", "San Francisco", "San Diego"]
#   color_key_colors=OrderedCollections.OrderedDict{Any, Any}(RGB{Float32}(0.0, 1.0, 1.0) => 1, RGB{Float32}(1.0, 0.0, 0.0) => 2)
#   color_key_title="country"
#   titles=Dict{Symbol, AbstractString}(:color => "country", :alpha => "alpha", :y => "rides_per_capita", :label => "name", :size => "population", :x => "population_density")
#   size_key_title="population"
#   size_key_vals=OrderedCollections.OrderedDict{Measures.AbsoluteLength, Int64}(0.5mm => 1, 2.25mm => 2, 2.974873734152916mm => 3, 3.531088913245535mm => 4, 4.0mm => 5)
#   x_label=Gadfly.Scale.identity_formatter
#   y_label=Gadfly.Scale.identity_formatter
#   xtick_label=Showoff.showoff
#   ytick_label=Showoff.showoff
#   color_label=Gadfly.Scale.var"#labeler#apply_scale##10"{Dict{ColorTypes.RGB{Float32}, String}}(Dict{ColorTypes.RGB{Float32}, String}(RGB(0.0, 1.0, 1.0) => "us", RGB(1.0, 0.0, 0.0) => "canada"))
#   xgroup_label=Showoff.showoff
#   ygroup_label=Showoff.showoff
#   shape_label=Showoff.showoff
#   size_label=Gadfly.Scale.var"#labeler#apply_scale##37"{Dict{Measures.AbsoluteLength, String}}(Dict{Measures.AbsoluteLength, String}(0.5mm => "0", 3.531088913245535mm => "1.50×10⁷", 2.25mm => "5.00×10⁶", 4.0mm => "2.00×10⁷", 2.974873734152916mm => "1.00×10⁷"))
# )
# ), 0, false, false, nothing, nothing)]), List([]), List([]), 0, false, false, false, false, nothing, nothing, 0.0, Symbol("")), Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.TextPrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Compose.Rotation{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}, Tuple{Measures.AbsoluteLength, Measures.AbsoluteLength}}}(Compose.TextPrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Compose.Rotation{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}, Tuple{Measures.AbsoluteLength, Measures.AbsoluteLength}}[Compose.TextPrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Compose.Rotation{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}, Tuple{Measures.AbsoluteLength, Measures.AbsoluteLength}}((1756.9398152761387cx, 24.97878578640524cy), "1756.9398152761387\n24.97878578640524", Compose.HLeft(), Compose.VBottom(), Compose.Rotation{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}(0.0, (0.5w, 0.5h)), (0.0mm, 0.0mm))], Symbol(""))]), List([Compose.Property{Compose.JSCallPrimitive}(Compose.JSCallPrimitive[Compose.JSCallPrimitive("data(\"ilabel\", \"13canada\")\n.mouseenter(Gadfly.datatip_visible)\n.mouseleave(Gadfly.datatip_hidden)\n", Measures.Measure[])]), Compose.Property{Compose.FillOpacityPrimitive}(Compose.FillOpacityPrimitive[Compose.FillOpacityPrimitive(0.0)]), Compose.Property{Compose.SVGAttributePrimitive}(Compose.SVGAttributePrimitive[Compose.SVGAttributePrimitive("ilabel", "13canada")]), Compose.Property{Compose.SVGClassPrimitive}(Compose.SVGClassPrimitive[Compose.SVGClassPrimitive("datatip")])]), 2, false, false, false, false, nothing, nothing, 0.0, Symbol("")), Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.CirclePrimitive{Tuple{Measures.Measure, Measures.Measure}, Measures.Measure}}(Compose.CirclePrimitive{Tuple{Measures.Measure, Measures.Measure}, Measures.Measure}[Compose.CirclePrimitive{Tuple{Measures.Measure, Measures.Measure}, Measures.Measure}((1756.9398152761387cx, 24.97878578640524cy), 1.8713346601030691mm)], Symbol(""))]), List([Compose.Property{Compose.FillOpacityPrimitive}(Compose.FillOpacityPrimitive[Compose.FillOpacityPrimitive(0.5)]), Compose.Property{Compose.StrokePrimitive}(Compose.StrokePrimitive[Compose.StrokePrimitive(RGBA{Float64}(0.0, 0.0, 0.0, 1.0))]), Compose.Property{Compose.FillPrimitive}(Compose.FillPrimitive[Compose.FillPrimitive(RGBA{Float64}(1.0, 0.0, 0.0, 1.0))]), Compose.Property{Compose.SVGClassPrimitive}(Compose.S ...

# %%
out |> SVG("out.svg", 16inch, 5inch)
# Out:
# false
